# %%
#first start python, then import the packages you want to use.
#You can also put all of this in a .py file and run that by typing
# python filename.py
#
# OR you can import the file itself while you are inside ipython and it will execute
#
# Matplotlib has an excellent plot gallery which you can browse and then see the
# code that made the plot you'd like:  http://matplotlib.org/gallery.html

# %matplotlib inline 
from astropy.io import ascii
from astropy import table
import matplotlib.pyplot as plt #this syntax means you can call the function with plt
import numpy as np #same here, you don't have to say numpy.mean you can say np.mean

# %% [markdown]
# <h3> read in your csv file, I've created a file of fake stuff which looks like this:</h3>
# <code>
# id,first_name,last_name,email,country,ip_address
# 1,Edward,Little,elittle0@123-reg.co.uk,Philippines,150.82.68.61
# 2,Karen,Medina,kmedina1@toplist.cz,Belarus,134.180.95.112
# 3,Sarah,Warren,swarren2@ocn.ne.jp,Brazil,238.31.34.51
# 4,Nancy,Porter,nporter3@xrea.com,China,141.54.91.237
# 5,Cynthia,Ryan,cryan4@merriam-webster.com,China,240.253.168.2
# 6,Christine,Reid,creid5@fotki.com,Philippines,235.144.30.199

# %%
mydata=ascii.read('MOCK_DATA.csv') #it will do some guesswork with what you give it, but you can also specify formatting

# %%
mydata #prints a nice HTML table in the notebook
# Out:
# <Table masked=False length=100>
#   id  first_name last_name ...     country         ip_address
# int64  string72   string80 ...    string176        string120
# ----- ---------- --------- ... ---------------- ---------------
#     1     Edward    Little ...      Philippines    150.82.68.61
#     2      Karen    Medina ...          Belarus  134.180.95.112
#     3      Sarah    Warren ...           Brazil    238.31.34.51
#     4      Nancy    Porter ...            China   141.54.91.237
#     5    Cynthia      Ryan ...            China   240.253.168.2
#     6  Christine      Reid ...      Philippines  235.144.30.199
#     7    Melissa    Rivera ...            China 160.228.167.157
#     8       Ryan    Carter ...         Honduras    67.42.75.243
#     9       Jane    Miller ...            China 106.226.168.245
#    10     Thomas    Weaver ...            China   134.222.9.178
#   ...        ...       ... ...              ...             ...
#    91    Lillian      Shaw ...            Japan   92.67.199.158
#    92     Samuel    Watson ...           Russia   248.6.159.147
#    93   Jonathan      Reid ...         Slovenia   187.82.21.220
#    94      Steve Armstrong ...            China   245.248.7.239
#    95      Roger     Perry ...            China  171.194.230.91
#    96        Ann      Boyd ...           Brazil   218.22.225.99
#    97    Michael     Lewis ...        Indonesia  228.144.235.44
#    98    Lillian      Hill ... Papua New Guinea   108.56.214.12
#    99    Lillian   Johnson ...            China    249.10.42.51
#   100      Laura     James ...        Indonesia 117.207.220.225

# %%
#now lets add a column to the table of data with some random numbers to plot
mydata['random']=np.random.rand(100) #add a random list of numbers

# %%
mydata #is it in there?
# Out:
# <Table masked=False length=100>
#   id  first_name last_name ...     country         ip_address        random
# int64  string72   string80 ...    string176        string120        float64
# ----- ---------- --------- ... ---------------- --------------- ---------------
#     1     Edward    Little ...      Philippines    150.82.68.61  0.494520597337
#     2      Karen    Medina ...          Belarus  134.180.95.112  0.289845931316
#     3      Sarah    Warren ...           Brazil    238.31.34.51 0.0414157138046
#     4      Nancy    Porter ...            China   141.54.91.237  0.406380758172
#     5    Cynthia      Ryan ...            China   240.253.168.2  0.619920719204
#     6  Christine      Reid ...      Philippines  235.144.30.199  0.503942940748
#     7    Melissa    Rivera ...            China 160.228.167.157  0.301516515341
#     8       Ryan    Carter ...         Honduras    67.42.75.243  0.704877743324
#     9       Jane    Miller ...            China 106.226.168.245  0.820831813621
#    10     Thomas    Weaver ...            China   134.222.9.178   0.47967175912
#   ...        ...       ... ...              ...             ...             ...
#    91    Lillian      Shaw ...            Japan   92.67.199.158  0.317876244377
#    92     Samuel    Watson ...           Russia   248.6.159.147  0.636703417648
#    93   Jonathan      Reid ...         Slovenia   187.82.21.220  0.559439182586
#    94      Steve Armstrong ...            China   245.248.7.239   0.71415277566
#    95      Roger     Perry ...            China  171.194.230.91 0.0060359445533
#    96        Ann      Boyd ...           Brazil   218.22.225.99  0.652625069346
#    97    Michael     Lewis ...        Indonesia  228.144.235.44  0.948495930874
#    98    Lillian      Hill ... Papua New Guinea   108.56.214.12  0.728972017582
#    99    Lillian   Johnson ...            China    249.10.42.51  0.688664065408
#   100      Laura     James ...        Indonesia 117.207.220.225  0.866054250663

# %%
#so lets plot the ID vs random
plt.plot(mydata['id'],mydata['random'])
plt.title("Person ID versus Random Number")
plt.xlabel("ID")
plt.ylabel(mydata['random'].name) #ooo, fancy

# %%
#how about plus signs that are green instead of connected points?
plt.plot(mydata['id'],mydata['random'],"g+")

# %%
#lets just look at people from China?
subtable = mydata[mydata['country'] == "China"]

# %%
subtable
# Out:
# <Table masked=False length=23>
#   id  first_name last_name ...  country     ip_address        random
# int64  string72   string80 ... string176    string120        float64
# ----- ---------- --------- ... --------- --------------- ----------------
#     4      Nancy    Porter ...     China   141.54.91.237   0.406380758172
#     5    Cynthia      Ryan ...     China   240.253.168.2   0.619920719204
#     7    Melissa    Rivera ...     China 160.228.167.157   0.301516515341
#     9       Jane    Miller ...     China 106.226.168.245   0.820831813621
#    10     Thomas    Weaver ...     China   134.222.9.178    0.47967175912
#    19      Jimmy    Fisher ...     China     34.55.70.58 0.00877312890271
#    27      Alice     Allen ...     China  231.204.181.97   0.708037589884
#    30       Ryan     Ortiz ...     China      7.30.45.78   0.896479463919
#    32      Donna      Reid ...     China   175.50.24.218   0.538032562421
#    42    Gregory    Warren ...     China   35.144.47.134   0.894386785817
#   ...        ...       ... ...       ...             ...              ...
#    54     Louise  Gonzales ...     China    50.79.44.211   0.591076703526
#    58      Wanda    Watson ...     China  21.232.139.174    0.16295963433
#    62    Richard     Welch ...     China   90.209.128.83  0.0782631964479
#    68  Christina    Porter ...     China   134.190.53.26   0.971188516319
#    73      Aaron Gutierrez ...     China  164.154.84.231   0.837672040531
#    80   Margaret   Stewart ...     China   119.29.199.46   0.151119441736
#    90     Teresa Patterson ...     China   6.202.225.248   0.408303806967
#    94      Steve Armstrong ...     China   245.248.7.239    0.71415277566
#    95      Roger     Perry ...     China  171.194.230.91  0.0060359445533
#    99    Lillian   Johnson ...     China    249.10.42.51   0.688664065408

# %%
#how about making a bar graph of number of people from each country
countries=np.unique(mydata['country']) #returns a list of unique names

# %%
countries
# Out:
# <Column name='country' dtype='string176' length=41>
#                Albania
#              Argentina
#                Belarus
# Bosnia and Herzegovina
#                 Brazil
#               Cambodia
#         Cayman Islands
#                  China
#                 Cyprus
#         Czech Republic
#     Dominican Republic
#                Ecuador
#                    ...
#  Palestinian Territory
#       Papua New Guinea
#                   Peru
#            Philippines
#                 Poland
#               Portugal
#                 Russia
#               Slovenia
#               Thailand
#                   Togo
#          United States
#                Vietnam

# %%
#now we count the members for each country and save as a list
count=list()
for country in countries:
    count.append(len(mydata[mydata['country']==country]))

# %%
y_pos=np.arange(len(countries))
plt.barh(y_pos, count, align='center', alpha=0.4)
plt.yticks(y_pos, countries)
plt.xlabel('Number of People in each country')
plt.title('Country Representation')

# %%
#that's a lot of countries, let's just plot the first 10
small_count=count[:10] #take the first 10
small_country=countries[:10]

# %%
y_pos=np.arange(len(small_country))
plt.barh(y_pos, small_count, align='center', alpha=0.4)
plt.yticks(y_pos, countries)
plt.xlabel('Number of People in each country')
plt.title('Country Representation')
